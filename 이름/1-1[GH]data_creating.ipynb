# %% [markdown]
# ## 그로스해킹 스터디_1회차 과제
# - 학습 내용 : AARRR, 퍼널, 전환율, 이탈율
# - 활용 데이터 : [kaggle e-commerce_website](https://www.kaggle.com/datasets/aerodinamicc/ecommerce-website-funnel-analysis?select=search_page_table.csv)
# - 제작일 : 2025-10-22 21:39
#
# <분석 흐름>
# 1. 데이터 불러오기
# 2. 데이터 병합 및 정제
# 3. 집계
# 4. 인사이트 도출

# %%
import pandas as pd
import os

# 1. 데이터 불러오기
user= pd.read_csv('01.ecommerce_website/user_table.csv')
homepage= pd.read_csv('01.ecommerce_website/home_page_table.csv')
search= pd.read_csv('01.ecommerce_website/search_page_table.csv')
payment= pd.read_csv('01.ecommerce_website/payment_page_table.csv')
payment_confirm= pd.read_csv('01.ecommerce_website/payment_confirmation_table.csv')

# %% [markdown]
# ### 1. EDA

# %%
# 2. 월별 가입자수 집계
user['date']=pd.to_datetime(user['date'])
user['month']= user['date'].dt.strftime('%Y-%m')
user.groupby('month')['user_id'].nunique()
# Out:
# month
# 2015-01    22600
# 2015-02    22600
# 2015-03    22600
# 2015-04    22600
# Name: user_id, dtype: int64

# %%
user['date'].value_counts()
# Out:
# date
# 2015-02-08    877
# 2015-02-07    846
# 2015-02-02    845
# 2015-02-15    835
# 2015-02-25    830
#              ...
# 2015-01-13    693
# 2015-03-27    693
# 2015-01-26    686
# 2015-03-19    684
# 2015-01-18    668
# Name: count, Length: 120, dtype: int64

# %%
30200/90400
# Out:
# 0.334070796460177

# %%
user['user_id'].nunique()
# Out:
# 90400

# %% [markdown]
# ### 2. 데이터 병합

# %%
step1 = pd.merge(user,homepage, on='user_id', how='left')
step2 = step1.merge(search, on='user_id',how='left',suffixes=('_home','_search'))
step3=step2.merge(payment, on='user_id',how='left').merge(payment_confirm, on='user_id',how='left',suffixes=('_payment','_confirm'))

# %%
step3
# Out:
#        user_id       date   device     sex    month  page_home  page_search  \
# 0       450007 2015-02-28  Desktop  Female  2015-02  home_page          NaN
# 1       756838 2015-01-13  Desktop    Male  2015-01  home_page          NaN
# 2       568983 2015-04-09  Desktop    Male  2015-04  home_page  search_page
# 3       190794 2015-02-18  Desktop  Female  2015-02  home_page  search_page
# 4       537909 2015-01-15  Desktop    Male  2015-01  home_page          NaN
# ...        ...        ...      ...     ...      ...        ...          ...
# 90395   307667 2015-03-30  Desktop  Female  2015-03  home_page          NaN
# 90396   642989 2015-02-08  Desktop  Female  2015-02  home_page  search_page
# 90397   659645 2015-04-13  Desktop    Male  2015-04  home_page  search_page
# 90398   359779 2015-03-23  Desktop    Male  2015-03  home_page          NaN
# 90399   438929 2015-03-26   Mobile  Female  2015-03  home_page          NaN
#
#       page_payment page_confirm
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 90395          NaN          NaN
# 90396          NaN          NaN
# 90397          NaN          NaN
# 90398          NaN          NaN
# 90399          NaN          NaN
#
# [90400 rows x 9 columns]

# %% [markdown]
# ### 4. 데이터 집계 (전환율, 이탈율)

# %%
step_counts = step3.groupby('page_home')['user_id'].nunique()
step_counts[0]
# Out:
# C:\Users\damla\AppData\Local\Temp\ipykernel_18160\791337342.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   step_counts[0]
# np.int64(90400)

# %%
step3.notnull().sum()
# Out:
# user_id         90400
# date            90400
# device          90400
# sex             90400
# month           90400
# page_home       90400
# page_search     45200
# page_payment     6030
# page_confirm      452
# dtype: int64

# %%
home_num = step3['page_home'].notnull().sum()
search_num = step3['page_search'].notnull().sum()
payment_num = step3['page_payment'].notnull().sum()
confirm_num = step3['page_confirm'].notnull().sum()

# %%
data = {
    '가입' : [home_num],
    '검색' : [search_num],
    '주문' : [payment_num],
    '결제완료' : [confirm_num]
}

user_num_by_step = pd.DataFrame(data, index=['유저수 (unique)'])
user_num_by_step
# Out:
#                  가입     검색    주문  결제완료
# 유저수 (unique)  90400  45200  6030   452

# %%
# 전환율 / 이탈율 계산
conversion_rate = [
    round(search_num / home_num * 100, 2),
    round(payment_num / search_num * 100, 2),
    round(confirm_num / payment_num * 100, 2)
]

churn_rate = [round(100 - c, 2) for c in conversion_rate]

# 전환율/이탈율 행 추가
user_num_by_step.loc['전환율 (%)'] = ['-', *conversion_rate]
user_num_by_step.loc['이탈율 (%)'] = ['-', *churn_rate]

# %%
user_num_by_step
# Out:
#                  가입       검색       주문   결제완료
# 유저수 (unique)  90400  45200.0  6030.00  452.0
# 전환율 (%)           -     50.0    13.34    7.5
# 이탈율 (%)           -     50.0    86.66   92.5

# %%
display(
    user_num_by_step.style
    .set_caption("과제1) 각 페이지별 전환율")
    .format(
        lambda x: "-" if pd.isna(x) or isinstance(x, str) else f"{x:.1f}"
    )
    .background_gradient(subset=['검색', '주문', '결제완료'], cmap='Blues')
)
# Out:
# <style type="text/css">
# #T_511ac_row0_col1, #T_511ac_row0_col2, #T_511ac_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_511ac_row1_col1, #T_511ac_row1_col2, #T_511ac_row1_col3, #T_511ac_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_511ac_row2_col2 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_511ac_row2_col3 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# </style>
# <table id="T_511ac">
#   <caption>과제1) 각 페이지별 전환율</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_511ac_level0_col0" class="col_heading level0 col0" >가입</th>
#       <th id="T_511ac_level0_col1" class="col_heading level0 col1" >검색</th>
#       <th id="T_511ac_level0_col2" class="col_heading level0 col2" >주문</th>
#       <th id="T_511ac_level0_col3" class="col_heading level0 col3" >결제완료</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_511ac_level0_row0" class="row_heading level0 row0" >유저수 (unique)</th>
#       <td id="T_511ac_row0_col0" class="data row0 col0" >90400.0</td>
#       <td id="T_511ac_row0_col1" class="data row0 col1" >45200.0</td>
#       <td id="T_511ac_row0_col2" class="data row0 col2" >6030.0</td>
#       <td id="T_511ac_row0_col3" class="data row0 col3" >452.0</td>
#     </tr>
#     <tr>
#       <th id="T_511ac_level0_row1" class="row_heading level0 row1" >전환율 (%)</th>
#       <td id="T_511ac_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_511ac_row1_col1" class="data row1 col1" >50.0</td>
#       <td id="T_511ac_row1_col2" class="data row1 col2" >13.3</td>
#       <td id="T_511ac_row1_col3" class="data row1 col3" >7.5</td>
#     </tr>
#     <tr>
#       <th id="T_511ac_level0_row2" class="row_heading level0 row2" >이탈율 (%)</th>
#       <td id="T_511ac_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_511ac_row2_col1" class="data row2 col1" >50.0</td>
#       <td id="T_511ac_row2_col2" class="data row2 col2" >86.7</td>
#       <td id="T_511ac_row2_col3" class="data row2 col3" >92.5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 장치별, 성별 전환율

# %%
def analysis_detail(column, feature):
    #1.단계별 값 집계
    home_num = step3[step3[column]==feature]['page_home'].notnull().sum()
    search_num = step3[step3[column]==feature]['page_search'].notnull().sum()
    payment_num = step3[step3[column]==feature]['page_payment'].notnull().sum()
    confirm_num = step3[step3[column]==feature]['page_confirm'].notnull().sum()

    #2.숫자로 저장
    data = {
    '가입' : [home_num],
    '검색' : [search_num],
    '주문' : [payment_num],
    '결제완료' : [confirm_num]
    }

    user_num_by_step = pd.DataFrame(data, index=['유저수 (unique)'])
    
    #3. 전환율, 이탈율 계산

    conversion_rate = [
        round(search_num / home_num * 100, 2),
        round(payment_num / search_num * 100, 2),
        round(confirm_num / payment_num * 100, 2)
    ]

    churn_rate = [round(100 - c, 2) for c in conversion_rate]

    # 전환율/이탈율 행 추가
    user_num_by_step.loc['전환율 (%)'] = ['-', *conversion_rate]
    user_num_by_step.loc['이탈율 (%)'] = ['-', *churn_rate]
    
    return display(
        user_num_by_step.style
        .set_caption(f"과제1) 각 페이지별 전환율_{column},{feature}")
        .format(
            lambda x: "-" if pd.isna(x) or isinstance(x, str) else f"{x:.1f}"
        )
        .background_gradient(subset=['검색', '주문', '결제완료'], cmap='Blues')
    )

# %%
analysis_detail('device', 'Desktop')
# Out:
# <style type="text/css">
# #T_6ad2d_row0_col1, #T_6ad2d_row0_col2, #T_6ad2d_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6ad2d_row1_col1, #T_6ad2d_row1_col2, #T_6ad2d_row1_col3, #T_6ad2d_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6ad2d_row2_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_6ad2d_row2_col3 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6ad2d">
#   <caption>과제1) 각 페이지별 전환율_device,Desktop</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ad2d_level0_col0" class="col_heading level0 col0" >가입</th>
#       <th id="T_6ad2d_level0_col1" class="col_heading level0 col1" >검색</th>
#       <th id="T_6ad2d_level0_col2" class="col_heading level0 col2" >주문</th>
#       <th id="T_6ad2d_level0_col3" class="col_heading level0 col3" >결제완료</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ad2d_level0_row0" class="row_heading level0 row0" >유저수 (unique)</th>
#       <td id="T_6ad2d_row0_col0" class="data row0 col0" >60200.0</td>
#       <td id="T_6ad2d_row0_col1" class="data row0 col1" >30100.0</td>
#       <td id="T_6ad2d_row0_col2" class="data row0 col2" >3010.0</td>
#       <td id="T_6ad2d_row0_col3" class="data row0 col3" >150.0</td>
#     </tr>
#     <tr>
#       <th id="T_6ad2d_level0_row1" class="row_heading level0 row1" >전환율 (%)</th>
#       <td id="T_6ad2d_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_6ad2d_row1_col1" class="data row1 col1" >50.0</td>
#       <td id="T_6ad2d_row1_col2" class="data row1 col2" >10.0</td>
#       <td id="T_6ad2d_row1_col3" class="data row1 col3" >5.0</td>
#     </tr>
#     <tr>
#       <th id="T_6ad2d_level0_row2" class="row_heading level0 row2" >이탈율 (%)</th>
#       <td id="T_6ad2d_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_6ad2d_row2_col1" class="data row2 col1" >50.0</td>
#       <td id="T_6ad2d_row2_col2" class="data row2 col2" >90.0</td>
#       <td id="T_6ad2d_row2_col3" class="data row2 col3" >95.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
analysis_detail('device', 'Mobile')
# Out:
# <style type="text/css">
# #T_27bfe_row0_col1, #T_27bfe_row0_col2, #T_27bfe_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_27bfe_row1_col1, #T_27bfe_row1_col2, #T_27bfe_row1_col3, #T_27bfe_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_27bfe_row2_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_27bfe_row2_col3 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# </style>
# <table id="T_27bfe">
#   <caption>과제1) 각 페이지별 전환율_device,Mobile</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27bfe_level0_col0" class="col_heading level0 col0" >가입</th>
#       <th id="T_27bfe_level0_col1" class="col_heading level0 col1" >검색</th>
#       <th id="T_27bfe_level0_col2" class="col_heading level0 col2" >주문</th>
#       <th id="T_27bfe_level0_col3" class="col_heading level0 col3" >결제완료</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27bfe_level0_row0" class="row_heading level0 row0" >유저수 (unique)</th>
#       <td id="T_27bfe_row0_col0" class="data row0 col0" >30200.0</td>
#       <td id="T_27bfe_row0_col1" class="data row0 col1" >15100.0</td>
#       <td id="T_27bfe_row0_col2" class="data row0 col2" >3020.0</td>
#       <td id="T_27bfe_row0_col3" class="data row0 col3" >302.0</td>
#     </tr>
#     <tr>
#       <th id="T_27bfe_level0_row1" class="row_heading level0 row1" >전환율 (%)</th>
#       <td id="T_27bfe_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_27bfe_row1_col1" class="data row1 col1" >50.0</td>
#       <td id="T_27bfe_row1_col2" class="data row1 col2" >20.0</td>
#       <td id="T_27bfe_row1_col3" class="data row1 col3" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_27bfe_level0_row2" class="row_heading level0 row2" >이탈율 (%)</th>
#       <td id="T_27bfe_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_27bfe_row2_col1" class="data row2 col1" >50.0</td>
#       <td id="T_27bfe_row2_col2" class="data row2 col2" >80.0</td>
#       <td id="T_27bfe_row2_col3" class="data row2 col3" >90.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
analysis_detail('sex', 'Female')
# Out:
# <style type="text/css">
# #T_6a922_row0_col1, #T_6a922_row0_col2, #T_6a922_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_6a922_row1_col1, #T_6a922_row1_col2, #T_6a922_row1_col3, #T_6a922_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_6a922_row2_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_6a922_row2_col3 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# </style>
# <table id="T_6a922">
#   <caption>과제1) 각 페이지별 전환율_sex,Female</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a922_level0_col0" class="col_heading level0 col0" >가입</th>
#       <th id="T_6a922_level0_col1" class="col_heading level0 col1" >검색</th>
#       <th id="T_6a922_level0_col2" class="col_heading level0 col2" >주문</th>
#       <th id="T_6a922_level0_col3" class="col_heading level0 col3" >결제완료</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a922_level0_row0" class="row_heading level0 row0" >유저수 (unique)</th>
#       <td id="T_6a922_row0_col0" class="data row0 col0" >45075.0</td>
#       <td id="T_6a922_row0_col1" class="data row0 col1" >22676.0</td>
#       <td id="T_6a922_row0_col2" class="data row0 col2" >3100.0</td>
#       <td id="T_6a922_row0_col3" class="data row0 col3" >241.0</td>
#     </tr>
#     <tr>
#       <th id="T_6a922_level0_row1" class="row_heading level0 row1" >전환율 (%)</th>
#       <td id="T_6a922_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_6a922_row1_col1" class="data row1 col1" >50.3</td>
#       <td id="T_6a922_row1_col2" class="data row1 col2" >13.7</td>
#       <td id="T_6a922_row1_col3" class="data row1 col3" >7.8</td>
#     </tr>
#     <tr>
#       <th id="T_6a922_level0_row2" class="row_heading level0 row2" >이탈율 (%)</th>
#       <td id="T_6a922_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_6a922_row2_col1" class="data row2 col1" >49.7</td>
#       <td id="T_6a922_row2_col2" class="data row2 col2" >86.3</td>
#       <td id="T_6a922_row2_col3" class="data row2 col3" >92.2</td>
#     </tr>
#   </tbody>
# </table>

# %%
analysis_detail('sex', 'Male')
# Out:
# <style type="text/css">
# #T_9b393_row0_col1, #T_9b393_row0_col2, #T_9b393_row0_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9b393_row1_col1, #T_9b393_row1_col2, #T_9b393_row1_col3, #T_9b393_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9b393_row2_col2 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_9b393_row2_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# </style>
# <table id="T_9b393">
#   <caption>과제1) 각 페이지별 전환율_sex,Male</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b393_level0_col0" class="col_heading level0 col0" >가입</th>
#       <th id="T_9b393_level0_col1" class="col_heading level0 col1" >검색</th>
#       <th id="T_9b393_level0_col2" class="col_heading level0 col2" >주문</th>
#       <th id="T_9b393_level0_col3" class="col_heading level0 col3" >결제완료</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b393_level0_row0" class="row_heading level0 row0" >유저수 (unique)</th>
#       <td id="T_9b393_row0_col0" class="data row0 col0" >45325.0</td>
#       <td id="T_9b393_row0_col1" class="data row0 col1" >22524.0</td>
#       <td id="T_9b393_row0_col2" class="data row0 col2" >2930.0</td>
#       <td id="T_9b393_row0_col3" class="data row0 col3" >211.0</td>
#     </tr>
#     <tr>
#       <th id="T_9b393_level0_row1" class="row_heading level0 row1" >전환율 (%)</th>
#       <td id="T_9b393_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_9b393_row1_col1" class="data row1 col1" >49.7</td>
#       <td id="T_9b393_row1_col2" class="data row1 col2" >13.0</td>
#       <td id="T_9b393_row1_col3" class="data row1 col3" >7.2</td>
#     </tr>
#     <tr>
#       <th id="T_9b393_level0_row2" class="row_heading level0 row2" >이탈율 (%)</th>
#       <td id="T_9b393_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_9b393_row2_col1" class="data row2 col1" >50.3</td>
#       <td id="T_9b393_row2_col2" class="data row2 col2" >87.0</td>
#       <td id="T_9b393_row2_col3" class="data row2 col3" >92.8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 전체 전환율
452/90400
# Out:
# 0.005

# %%
### 기초 과제용 데이터 저장
step3.to_csv("GH_1회차_과제용_ecommerce_website.csv",index=False)
